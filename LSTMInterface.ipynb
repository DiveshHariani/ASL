# %%
import cv2
import numpy as np
import tensorflow as tf
import pandas as pd
import mediapipe as mp
import os

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
class MediapipeUtil:
    @classmethod
    def MediapipeDetection(cls, image, model):
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
        image.flags.writeable = False                  
        results = model.process(image)                 
        image.flags.writeable = True                    
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        return image, results

    @classmethod
    def draw_landmarks(cls, image, results):
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
    
    @classmethod
    def draw_styled_landmarks(cls, image, results):
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                                mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                )  
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                )
    
    @classmethod
    def extract_keypoints(cls, results):
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.array([-2]*63)
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.array([-2]*63)
        return np.concatenate([lh, rh])
    
    @classmethod
    def videoUtil(cls):
        count = 0
        cap = cv2.VideoCapture(0)
        with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
            while cap.isOpened():
                count += 1
                ret, frame = cap.read()

                image, results = MediapipeUtil.MediapipeDetection(frame, holistic)

                MediapipeUtil.draw_styled_landmarks(image, results)
                keypoints = MediapipeUtil.extract_keypoints(results)
                print(keypoints)

                cv2.imshow('OpenCV Feed', cv2.flip(image, 1))

                if cv2.waitKey(5) & 0xFF == 27:
                    break
        print(count)
        cap.release()
        cv2.destroyAllWindows()

# %% [markdown]
# DATA_MP
# - Hello
#     - Video 1
#         - Frame 1
#         - Frame 2
#             ...
#         - Frame N
#     - Video 2
# ....

# %%
def createDirs(actions: list, no_videos: list):
    if len(actions) != len(no_videos):
        return False
    
    _DATA_PATH = 'DATA_MP'
    actions = np.array(actions)
    for ind, action in enumerate(actions):
        if _DATA_PATH not in os.listdir():
            os.makedirs(_DATA_PATH)
        
        if action not in os.listdir(os.path.join(_DATA_PATH)):
            videos = no_videos[ind]
            for vid in range(1, videos+1):
                try:
                    os.makedirs(os.path.join(_DATA_PATH, action, str(vid)))
                except:
                    pass
        else:
            print('Data Exist')
    return True

# %%
print(createDirs(['5', 'Hello'], [3, 30]))
# Out:
# True

# %%
def generateData():
    _DATA_PATH = 'DATA_MP'
    cap = cv2.VideoCapture(0)
    with mp_holistic.Holistic(min_detection_confidence=0.5,
                              min_tracking_confidence=0.5) as holistic:
        for ind, action in enumerate(actions):
            videos = no_videos[ind]

            # for each video in an action
            for vid in range(1, videos+1):
                # for each frame in an video
                for frame_num in range(1, frames[ind] + 1):
                    # Capture frame
                    ret, image = cap.read()
                    image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                    keypoints = MediapipeUtil.extract_keypoints(results)
                    MediapipeUtil.draw_styled_landmarks(results)

                    # for static images:
                    npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                    np.save(npy_path, keypoints)

                    # for dynamic signs:
                    if frame_num == 0:
                        cv2.putText(image, f'START Collecting frames for {action} Video Number {vid}', (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                        cv2.imshow('STARTING COLLECTION', image) # show image
                        cv2.waitKey(2000) # wait for 2 seconds
                    else:
                        cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    
                    image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                    keypoints = MediapipeUtil.extract_keypoints(results)
                    MediapipeUtil.draw_styled_landmarks(image, results)

                    cv2.imshow('Feed', image)
# Out:
# Data Exist
# Data Exist
# True

# %%
_DATA_PATH = 'DATA_MP'
cap = cv2.VideoCapture(0)
actions = ['5', 'Hello']
no_videos = [3, 30]
no_frames = [30, 30]
isDynamic = [False, True]

with mp_holistic.Holistic(min_detection_confidence=0.5,
                              min_tracking_confidence=0.5) as holistic:
        for ind, action in enumerate(actions):
            videos = no_videos[ind]

            # for each video in an action
            for vid in range(1, videos+1):
                # for each frame in an video
                for frame_num in range(1, no_frames[ind] + 1):
                    # Capture frame
                    ret, image = cap.read()
                    
                    # for static signs
                    if not isDynamic[ind]:
                        image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                        keypoints = MediapipeUtil.extract_keypoints(results)
                        MediapipeUtil.draw_styled_landmarks(image, results)

                        image = cv2.flip(image, 1)
                        cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                        cv2.imshow('Feed', image)

                        # for static images:
                        npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                        np.save(npy_path, keypoints)

                    # for dynamic signs:
                    else:
                        image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                        keypoints = MediapipeUtil.extract_keypoints(results)
                        MediapipeUtil.draw_styled_landmarks(image, results)

                        image = cv2.flip(image, 1)
                        if frame_num == 1:
                            cv2.putText(image, f'START Collecting frames for {action} Video Number {vid}', (15,12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                            cv2.imshow('Feed', image) # show image
                            cv2.waitKey(2000) # wait for 2 seconds
                        else:
                            cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                            cv2.imshow('Feed', image)

                        npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                        np.save(npy_path, keypoints)

                    if cv2.waitKey(5) & 0xFF == 27:
                        break

cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
class DataGenerator:
    _DATA_PATH = 'DATA_MP'

    def __init__(self, actions = [], videos = [], isDynamic = [], no_of_frames = 30):
        self.actions = actions
        self.no_videos = videos
        self.no_frames = no_of_frames
        self.isDynamic = isDynamic
    
    def createDirs(self):
        if len(self.actions) != len(self.no_videos):
            return False
        
        self.actions = np.array(self.actions)
        for ind, action in enumerate(self.actions):
            if _DATA_PATH not in os.listdir():
                os.makedirs(_DATA_PATH)
            
            if action not in os.listdir(os.path.join(_DATA_PATH)):
                videos = self.no_videos[ind]
                for vid in range(1, videos+1):
                    try:
                        os.makedirs(os.path.join(_DATA_PATH, action, str(vid)))
                    except:
                        pass
            else:
                print('Data Exist')
        return True
    
    def createData(self):
        cap = cv2.VideoCapture(0)

        with mp_holistic.Holistic(min_detection_confidence=0.5,
                                    min_tracking_confidence=0.5) as holistic:
                for ind, action in enumerate(self.actions):
                    videos = self.no_videos[ind]

                    # for each video in an action
                    for vid in range(1, videos+1):
                        # for each frame in an video
                        for frame_num in range(1, self.no_frames + 1):
                            # Capture frame
                            ret, image = cap.read()
                            
                            # for static signs
                            if not self.isDynamic[ind]:
                                image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                                keypoints = MediapipeUtil.extract_keypoints(results)
                                MediapipeUtil.draw_styled_landmarks(image, results)

                                image = cv2.flip(image, 1)
                                cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                                cv2.imshow('Feed', image)

                                # for static images:
                                npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                                np.save(npy_path, keypoints)

                            # for dynamic signs:
                            else:
                                image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                                keypoints = MediapipeUtil.extract_keypoints(results)
                                MediapipeUtil.draw_styled_landmarks(image, results)

                                image = cv2.flip(image, 1)
                                if frame_num == 1:
                                    cv2.putText(image, f'START Collecting frames for {action} Video Number {vid}', (15,12), 
                                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                                    cv2.imshow('Feed', image) # show image
                                    cv2.waitKey(2000) # wait for 2 seconds
                                else:
                                    cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                                    cv2.imshow('Feed', image)

                                npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                                np.save(npy_path, keypoints)

                            if cv2.waitKey(5) & 0xFF == 27:
                                break

        cap.release()
        cv2.destroyAllWindows()

    @classmethod
    def loadData(cls):
        sequences, labels = [], []
        actions = os.listdir(_DATA_PATH)
        label_map = {label: num for num, label in enumerate(actions)}
            
        for ind, action in enumerate(actions):
            no_videos = len(os.listdir(os.path.join(_DATA_PATH, action)))
            for vid in range(1, no_videos+1):
                no_frames = len(os.listdir(os.path.join(_DATA_PATH, action, str(vid))))
                window = []
                for frame_num in range(1, no_frames+1):
                    res = np.load(os.path.join(_DATA_PATH, action, str(vid), "{}.npy".format(frame_num)))
                    window.append(res)
                sequences.append(window)
                labels.append(label_map[action])

        return sequences, labels, actions

# %%
# Out:
# 3

# %%
os.listdir(os.path.join(_DATA_PATH, '5'))
# Out:
# ['1', '2', '3']

# %%
cap.release()
cv2.destroyAllWindows()

# %%
create_data = DataGenerator(['Thanks'], [30], [True])
create_data.createDirs()
# Out:
# Data Exist
# True

# %%
create_data.createData()

# %%
# class LSTMModel:
#     def __init__(self):
#         from tensorflow.keras.callbacks import TensorBoard
#         log_dir = os.path.join('Logs')
#         self.tb_callback = TensorBoard(log_dir=log_dir)

#     def getModel(self, load_from_file = None):
#         if not load_from_file:
#             from tensorflow.keras.models import Sequential
#             from tensorflow.keras.layers import LSTM, Dense

#             self.model = Sequential()
#             self.model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,126)))
#             self.model.add(LSTM(128, return_sequences=True, activation='relu'))
#             self.model.add(LSTM(64, return_sequences=False, activation='relu'))
#             self.model.add(Dense(64, activation='relu'))
#             self.model.add(Dense(32, activation='relu'))
#             self.model.add(Dense(np.array(actions).shape[0], activation='softmax'))

#             self.model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        
#         else:
#             self.model = tf.keras.load_model(load_from_file)
    
#     def trainModel(self, X_train, y_train, epochs = 1000):
#         history = self.model.fit(X_train, y_train, epochs=epochs, callbacks=[self.tb_callback])
        
#     def predict(self, y):
#         return self.model.predict(y)

# %% [markdown]
# Loading Data and testing the model

# %%
sequences, labels, actions = DataGenerator.loadData()
actions
# Out:
# ['5', 'Hello', 'Thanks']

# %%
actions = np.array(actions)
actions.shape[0]
# Out:
# 3

# %%
np.array(sequences).shape
# Out:
# (63, 30, 126)

# %%
np.array(labels).shape
# Out:
# (63,)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
X = np.array(sequences)
X.shape
# Out:
# (63, 30, 126)

# %%
y = to_categorical(labels).astype(int)

# %%
from collections import Counter
Counter(labels)
# Out:
# Counter({0: 3, 1: 30, 2: 30})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (56, 30, 126)
# (7, 30, 126)
# (56, 3)
# (7, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
log_dir = os.path.join('Logs')

model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,126)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
tb_callback = TensorBoard(log_dir=log_dir)
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 4.3145e-05 - categorical_accuracy: 1.0000
# Epoch 2/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 4.3011e-05 - categorical_accuracy: 1.0000
# Epoch 3/2000
# 2/2 [==============================] - 0s 117ms/step - loss: 4.3030e-05 - categorical_accuracy: 1.0000
# Epoch 4/2000
# 2/2 [==============================] - 0s 130ms/step - loss: 4.2887e-05 - categorical_accuracy: 1.0000
# Epoch 5/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 4.2879e-05 - categorical_accuracy: 1.0000
# Epoch 6/2000
# 2/2 [==============================] - 0s 113ms/step - loss: 4.2787e-05 - categorical_accuracy: 1.0000
# Epoch 7/2000
# 2/2 [==============================] - 0s 172ms/step - loss: 4.2821e-05 - categorical_accuracy: 1.0000
# Epoch 8/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 4.2849e-05 - categorical_accuracy: 1.0000
# Epoch 9/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 4.2623e-05 - categorical_accuracy: 1.0000
# Epoch 10/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 4.2570e-05 - categorical_accuracy: 1.0000
# Epoch 11/2000
# 2/2 [==============================] - 0s 138ms/step - loss: 4.2672e-05 - categorical_accuracy: 1.0000
# Epoch 12/2000
# 2/2 [==============================] - 0s 157ms/step - loss: 4.2700e-05 - categorical_accuracy: 1.0000
# Epoch 13/2000
# 2/2 [==============================] - 0s 171ms/step - loss: 4.2585e-05 - categorical_accuracy: 1.0000
# Epoch 14/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 4.2530e-05 - categorical_accuracy: 1.0000
# Epoch 15/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 4.2306e-05 - categorical_accuracy: 1.0000
# Epoch 16/2000
# 2/2 [==============================] - 0s 134ms/step - loss: 4.2391e-05 - categorical_accuracy: 1.0000
# Epoch 17/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 4.2296e-05 - categorical_accuracy: 1.0000
# Epoch 18/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 4.2262e-05 - categorical_accuracy: 1.0000
# Epoch 19/2000
# 2/2 [==============================] - 0s 147ms/step - loss: 4.2332e-05 - categorical_accuracy: 1.0000
# Epoch 20/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 4.2377e-05 - categorical_accuracy: 1.0000
# Epoch 21/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 4.2136e-05 - categorical_accuracy: 1.0000
# Epoch 22/2000
# 2/2 [==============================] - 0s 129ms/step - loss: 4.2113e-05 - categorical_accuracy: 1.0000
# Epoch 23/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 4.1942e-05 - categorical_accuracy: 1.0000
# Epoch 24/2000
# 2/2 [==============================] - 0s 111ms/step - loss: 4.2038e-05 - categorical_accuracy: 1.0000
# Epoch 25/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 4.2059e-05 - categorical_accuracy: 1.0000
# Epoch 26/2000
# 2/2 [==============================] - 0s 113ms/step - loss: 4.1887e-05 - categorical_accuracy: 1.0000
# Epoch 27/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 4.1806e-05 - categorical_accuracy: 1.0000
# Epoch 28/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 4.1770e-05 - categorical_accuracy: 1.0000
# Epoch 29/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 4.1783e-05 - categorical_accuracy: 1.0000
# Epoch 30/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 4.1685e-05 - categorical_accuracy: 1.0000
# Epoch 31/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 4.1517e-05 - categorical_accuracy: 1.0000
# Epoch 32/2000
# 2/2 [==============================] - 0s 127ms/step - loss: 4.1470e-05 - categorical_accuracy: 1.0000
# Epoch 33/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 4.1444e-05 - categorical_accuracy: 1.0000
# Epoch 34/2000
# 2/2 [==============================] - 0s 137ms/step - loss: 4.1434e-05 - categorical_accuracy: 1.0000
# Epoch 35/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 4.1662e-05 - categorical_accuracy: 1.0000
# Epoch 36/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 4.1278e-05 - categorical_accuracy: 1.0000
# Epoch 37/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 4.1361e-05 - categorical_accuracy: 1.0000
# Epoch 38/2000
# 2/2 [==============================] - 0s 107ms/step - loss: 4.1285e-05 - categorical_accuracy: 1.0000
# Epoch 39/2000
# 2/2 [==============================] - 0s 128ms/step - loss: 4.1119e-05 - categorical_accuracy: 1.0000
# Epoch 40/2000
# 2/2 [==============================] - 0s 171ms/step - loss: 4.1044e-05 - categorical_accuracy: 1.0000
# Epoch 41/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 4.1081e-05 - categorical_accuracy: 1.0000
# Epoch 42/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 4.1038e-05 - categorical_accuracy: 1.0000
# Epoch 43/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 4.1010e-05 - categorical_accuracy: 1.0000
# Epoch 44/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 4.0968e-05 - categorical_accuracy: 1.0000
# Epoch 45/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 4.0840e-05 - categorical_accuracy: 1.0000
# Epoch 46/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 4.0853e-05 - categorical_accuracy: 1.0000
# Epoch 47/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 4.0663e-05 - categorical_accuracy: 1.0000
# Epoch 48/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 4.0723e-05 - categorical_accuracy: 1.0000
# Epoch 49/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 4.0693e-05 - categorical_accuracy: 1.0000
# Epoch 50/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 4.0766e-05 - categorical_accuracy: 1.0000
# Epoch 51/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 4.0542e-05 - categorical_accuracy: 1.0000
# Epoch 52/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 4.0489e-05 - categorical_accuracy: 1.0000
# Epoch 53/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 4.0557e-05 - categorical_accuracy: 1.0000
# Epoch 54/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 4.0493e-05 - categorical_accuracy: 1.0000
# Epoch 55/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 4.0689e-05 - categorical_accuracy: 1.0000
# Epoch 56/2000
# 2/2 [==============================] - 0s 107ms/step - loss: 4.0281e-05 - categorical_accuracy: 1.0000
# Epoch 57/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 4.0210e-05 - categorical_accuracy: 1.0000
# Epoch 58/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 4.0225e-05 - categorical_accuracy: 1.0000
# Epoch 59/2000
# 2/2 [==============================] - 0s 117ms/step - loss: 4.0378e-05 - categorical_accuracy: 1.0000
# Epoch 60/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 4.0378e-05 - categorical_accuracy: 1.0000
# Epoch 61/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 4.0242e-05 - categorical_accuracy: 1.0000
# Epoch 62/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 4.0076e-05 - categorical_accuracy: 1.0000
# Epoch 63/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 3.9874e-05 - categorical_accuracy: 1.0000
# Epoch 64/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 3.9889e-05 - categorical_accuracy: 1.0000
# Epoch 65/2000
# 2/2 [==============================] - 0s 127ms/step - loss: 3.9898e-05 - categorical_accuracy: 1.0000
# Epoch 66/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 3.9902e-05 - categorical_accuracy: 1.0000
# Epoch 67/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 3.9902e-05 - categorical_accuracy: 1.0000
# Epoch 68/2000
# 2/2 [==============================] - 0s 207ms/step - loss: 3.9859e-05 - categorical_accuracy: 1.0000
# Epoch 69/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 3.9595e-05 - categorical_accuracy: 1.0000
# Epoch 70/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 3.9574e-05 - categorical_accuracy: 1.0000
# Epoch 71/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 3.9634e-05 - categorical_accuracy: 1.0000
# Epoch 72/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 3.9521e-05 - categorical_accuracy: 1.0000
# Epoch 73/2000
# 2/2 [==============================] - 0s 132ms/step - loss: 3.9327e-05 - categorical_accuracy: 1.0000
# Epoch 74/2000
# 2/2 [==============================] - 0s 116ms/step - loss: 3.9523e-05 - categorical_accuracy: 1.0000
# Epoch 75/2000
# 2/2 [==============================] - 0s 107ms/step - loss:
2000
# 2/2 [==============================] - 0s 140ms/step - loss: 3.5735e-05 - categorical_accuracy: 1.0000
# Epoch 155/2000
# 2/2 [==============================] - 0s 139ms/step - loss: 3.6010e-05 - categorical_accuracy: 1.0000
# Epoch 156/2000
# 2/2 [==============================] - 0s 148ms/step - loss: 3.5774e-05 - categorical_accuracy: 1.0000
# Epoch 157/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 3.5680e-05 - categorical_accuracy: 1.0000
# Epoch 158/2000
# 2/2 [==============================] - 0s 145ms/step - loss: 3.5722e-05 - categorical_accuracy: 1.0000
# Epoch 159/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 3.5484e-05 - categorical_accuracy: 1.0000
# Epoch 160/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 3.5491e-05 - categorical_accuracy: 1.0000
# Epoch 161/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 3.5456e-05 - categorical_accuracy: 1.0000
# Epoch 162/2000
# 2/2 [==============================] - 0s 139ms/step - loss: 3.5395e-05 - categorical_accuracy: 1.0000
# Epoch 163/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 3.5452e-05 - categorical_accuracy: 1.0000
# Epoch 164/2000
# 2/2 [==============================] - 0s 121ms/step - loss: 3.5342e-05 - categorical_accuracy: 1.0000
# Epoch 165/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 3.5207e-05 - categorical_accuracy: 1.0000
# Epoch 166/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 3.5456e-05 - categorical_accuracy: 1.0000
# Epoch 167/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 3.5227e-05 - categorical_accuracy: 1.0000
# Epoch 168/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 3.5159e-05 - categorical_accuracy: 1.0000
# Epoch 169/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 3.5093e-05 - categorical_accuracy: 1.0000
# Epoch 170/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 3.5031e-05 - categorical_accuracy: 1.0000
# Epoch 171/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 3.5099e-05 - categorical_accuracy: 1.0000
# Epoch 172/2000
# 2/2 [==============================] - 0s 117ms/step - loss: 3.5131e-05 - categorical_accuracy: 1.0000
# Epoch 173/2000
# 2/2 [==============================] - 0s 154ms/step - loss: 3.5073e-05 - categorical_accuracy: 1.0000
# Epoch 174/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 3.4822e-05 - categorical_accuracy: 1.0000
# Epoch 175/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 3.5184e-05 - categorical_accuracy: 1.0000
# Epoch 176/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 3.5046e-05 - categorical_accuracy: 1.0000
# Epoch 177/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 3.4935e-05 - categorical_accuracy: 1.0000
# Epoch 178/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 3.4922e-05 - categorical_accuracy: 1.0000
# Epoch 179/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 3.4780e-05 - categorical_accuracy: 1.0000
# Epoch 180/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 3.4829e-05 - categorical_accuracy: 1.0000
# Epoch 181/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 3.4607e-05 - categorical_accuracy: 1.0000
# Epoch 182/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 3.4693e-05 - categorical_accuracy: 1.0000
# Epoch 183/2000
# 2/2 [==============================] - 0s 120ms/step - loss: 3.4488e-05 - categorical_accuracy: 1.0000
# Epoch 184/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 3.4597e-05 - categorical_accuracy: 1.0000
# Epoch 185/2000
# 2/2 [==============================] - 0s 125ms/step - loss: 3.4514e-05 - categorical_accuracy: 1.0000
# Epoch 186/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 3.4558e-05 - categorical_accuracy: 1.0000
# Epoch 187/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 3.4565e-05 - categorical_accuracy: 1.0000
# Epoch 188/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 3.4341e-05 - categorical_accuracy: 1.0000
# Epoch 189/2000
# 2/2 [==============================] - 0s 143ms/step - loss: 3.4344e-05 - categorical_accuracy: 1.0000
# Epoch 190/2000
# 2/2 [==============================] - 0s 187ms/step - loss: 3.4237e-05 - categorical_accuracy: 1.0000
# Epoch 191/2000
# 2/2 [==============================] - 0s 143ms/step - loss: 3.4246e-05 - categorical_accuracy: 1.0000
# Epoch 192/2000
# 2/2 [==============================] - 0s 143ms/step - loss: 3.4133e-05 - categorical_accuracy: 1.0000
# Epoch 193/2000
# 2/2 [==============================] - 0s 107ms/step - loss: 3.4101e-05 - categorical_accuracy: 1.0000
# Epoch 194/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 3.4052e-05 - categorical_accuracy: 1.0000
# Epoch 195/2000
# 2/2 [==============================] - 0s 123ms/step - loss: