# %%
import cv2
import numpy as np
import tensorflow as tf
import pandas as pd
import mediapipe as mp
import os

mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
class MediapipeUtil:
    @classmethod
    def MediapipeDetection(cls, image, model):
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
        image.flags.writeable = False                  
        results = model.process(image)                 
        image.flags.writeable = True                    
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        return image, results

    @classmethod
    def draw_landmarks(cls, image, results):
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
    
    @classmethod
    def draw_styled_landmarks(cls, image, results):
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                                mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                )  
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                )
    
    @classmethod
    def extract_keypoints(cls, results):
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.array([-2]*63)
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.array([-2]*63)
        return np.concatenate([lh, rh])
    
    @classmethod
    def videoUtil(cls):
        cap = cv2.VideoCapture(0)
        with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
            while cap.isOpened():
                ret, frame = cap.read()

                image, results = MediapipeUtil.MediapipeDetection(frame, holistic)

                MediapipeUtil.draw_styled_landmarks(image, results)
                keypoints = MediapipeUtil.extract_keypoints(results)
                print(keypoints)

                cv2.imshow('OpenCV Feed', cv2.flip(image, 1))

                if cv2.waitKey(5) & 0xFF == 27:
                    break

        cap.release()
        cv2.destroyAllWindows()

# %% [markdown]
# DATA_MP
# - Hello
#     - Video 1
#         - Frame 1
#         - Frame 2
#             ...
#         - Frame N
#     - Video 2
# ....

# %%
def createDirs(actions: list, no_videos: list):
    if len(actions) != len(no_videos):
        return False
    
    _DATA_PATH = 'DATA_MP'
    actions = np.array(actions)
    for ind, action in enumerate(actions):
        if _DATA_PATH not in os.listdir():
            os.makedirs(_DATA_PATH)
        
        if action not in os.listdir(os.path.join(_DATA_PATH)):
            videos = no_videos[ind]
            for vid in range(1, videos+1):
                try:
                    os.makedirs(os.path.join(_DATA_PATH, action, str(vid)))
                except:
                    pass
        else:
            print('Data Exist')
    return True

# %%
print(createDirs(['5', 'Hello'], [3, 30]))
# Out:
# True

# %%
def generateData():
    _DATA_PATH = 'DATA_MP'
    cap = cv2.VideoCapture(0)
    with mp_holistic.Holistic(min_detection_confidence=0.5,
                              min_tracking_confidence=0.5) as holistic:
        for ind, action in enumerate(actions):
            videos = no_videos[ind]

            # for each video in an action
            for vid in range(1, videos+1):
                # for each frame in an video
                for frame_num in range(1, frames[ind] + 1):
                    # Capture frame
                    ret, image = cap.read()
                    image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                    keypoints = MediapipeUtil.extract_keypoints(results)
                    MediapipeUtil.draw_styled_landmarks(results)

                    # for static images:
                    npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                    np.save(npy_path, keypoints)

                    # for dynamic signs:
                    if frame_num == 0:
                        cv2.putText(image, f'START Collecting frames for {action} Video Number {vid}', (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                        cv2.imshow('STARTING COLLECTION', image) # show image
                        cv2.waitKey(2000) # wait for 2 seconds
                    else:
                        cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    
                    image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                    keypoints = MediapipeUtil.extract_keypoints(results)
                    MediapipeUtil.draw_styled_landmarks(image, results)

                    cv2.imshow('Feed', image)
# Out:
# Data Exist
# Data Exist
# True

# %%
_DATA_PATH = 'DATA_MP'
cap = cv2.VideoCapture(0)
actions = ['5', 'Hello']
no_videos = [3, 30]
no_frames = [30, 30]
isDynamic = [False, True]

with mp_holistic.Holistic(min_detection_confidence=0.5,
                              min_tracking_confidence=0.5) as holistic:
        for ind, action in enumerate(actions):
            videos = no_videos[ind]

            # for each video in an action
            for vid in range(1, videos+1):
                # for each frame in an video
                for frame_num in range(1, no_frames[ind] + 1):
                    # Capture frame
                    ret, image = cap.read()
                    
                    # for static signs
                    if not isDynamic[ind]:
                        image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                        keypoints = MediapipeUtil.extract_keypoints(results)
                        MediapipeUtil.draw_styled_landmarks(image, results)

                        image = cv2.flip(image, 1)
                        cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                        cv2.imshow('Feed', image)

                        # for static images:
                        npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                        np.save(npy_path, keypoints)

                    # for dynamic signs:
                    else:
                        image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                        keypoints = MediapipeUtil.extract_keypoints(results)
                        MediapipeUtil.draw_styled_landmarks(image, results)

                        image = cv2.flip(image, 1)
                        if frame_num == 1:
                            cv2.putText(image, f'START Collecting frames for {action} Video Number {vid}', (15,12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                            cv2.imshow('Feed', image) # show image
                            cv2.waitKey(2000) # wait for 2 seconds
                        else:
                            cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                            cv2.imshow('Feed', image)

                        npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                        np.save(npy_path, keypoints)

                    if cv2.waitKey(5) & 0xFF == 27:
                        break

cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
class DataGenerator:
    _DATA_PATH = 'DATA_MP'

    def __init__(self, actions = [], videos = [], isDynamic = [], no_of_frames = 30):
        self.actions = actions
        self.no_videos = videos
        self.no_frames = no_of_frames
        self.isDynamic = isDynamic
    
    def createDirs(self):
        if len(self.actions) != len(self.no_videos):
            return False
        
        self.actions = np.array(self.actions)
        for ind, action in enumerate(self.actions):
            if _DATA_PATH not in os.listdir():
                os.makedirs(_DATA_PATH)
            
            if action not in os.listdir(os.path.join(_DATA_PATH)):
                videos = self.no_videos[ind]
                for vid in range(1, videos+1):
                    try:
                        os.makedirs(os.path.join(_DATA_PATH, action, str(vid)))
                    except:
                        pass
            else:
                print('Data Exist')
        return True
    
    def createData(self):
        cap = cv2.VideoCapture(0)

        with mp_holistic.Holistic(min_detection_confidence=0.5,
                                    min_tracking_confidence=0.5) as holistic:
                for ind, action in enumerate(self.actions):
                    videos = self.no_videos[ind]

                    # for each video in an action
                    for vid in range(1, videos+1):
                        # for each frame in an video
                        for frame_num in range(1, self.no_frames + 1):
                            # Capture frame
                            ret, image = cap.read()
                            
                            # for static signs
                            if not self.isDynamic[ind]:
                                image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                                keypoints = MediapipeUtil.extract_keypoints(results)
                                MediapipeUtil.draw_styled_landmarks(image, results)

                                image = cv2.flip(image, 1)
                                cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                                cv2.imshow('Feed', image)

                                # for static images:
                                npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                                np.save(npy_path, keypoints)

                            # for dynamic signs:
                            else:
                                image, results = MediapipeUtil.MediapipeDetection(image, holistic)
                                keypoints = MediapipeUtil.extract_keypoints(results)
                                MediapipeUtil.draw_styled_landmarks(image, results)

                                image = cv2.flip(image, 1)
                                if frame_num == 1:
                                    cv2.putText(image, f'START Collecting frames for {action} Video Number {vid}', (15,12), 
                                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                                    cv2.imshow('Feed', image) # show image
                                    cv2.waitKey(2000) # wait for 2 seconds
                                else:
                                    cv2.putText(image, f'Collecting frames for {action} Video Number {vid}', (15,12), 
                                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                                    cv2.imshow('Feed', image)

                                npy_path = os.path.join(_DATA_PATH, action, str(vid), str(frame_num))
                                np.save(npy_path, keypoints)

                            if cv2.waitKey(5) & 0xFF == 27:
                                break

        cap.release()
        cv2.destroyAllWindows()

    @classmethod
    def loadData(cls):
        sequences, labels = [], []
        actions = os.listdir(_DATA_PATH)
        label_map = {label: num for num, label in enumerate(actions)}
            
        for ind, action in enumerate(actions):
            no_videos = len(os.listdir(os.path.join(_DATA_PATH, action)))
            for vid in range(1, no_videos+1):
                no_frames = len(os.listdir(os.path.join(_DATA_PATH, action, str(vid))))
                window = []
                for frame_num in range(1, no_frames+1):
                    res = np.load(os.path.join(_DATA_PATH, action, str(vid), "{}.npy".format(frame_num)))
                    window.append(res)
                sequences.append(window)
                labels.append(label_map[action])

        return sequences, labels, actions

# %%
# Out:
# 3

# %%
os.listdir(os.path.join(_DATA_PATH, '5'))
# Out:
# ['1', '2', '3']

# %%
cap.release()
cv2.destroyAllWindows()

# %%
create_data = DataGenerator(['Thanks'], [30], [True])
create_data.createDirs()
# Out:
# Data Exist
# True

# %%
create_data.createData()

# %%
# class LSTMModel:
#     def __init__(self):
#         from tensorflow.keras.callbacks import TensorBoard
#         log_dir = os.path.join('Logs')
#         self.tb_callback = TensorBoard(log_dir=log_dir)

#     def getModel(self, load_from_file = None):
#         if not load_from_file:
#             from tensorflow.keras.models import Sequential
#             from tensorflow.keras.layers import LSTM, Dense

#             self.model = Sequential()
#             self.model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,126)))
#             self.model.add(LSTM(128, return_sequences=True, activation='relu'))
#             self.model.add(LSTM(64, return_sequences=False, activation='relu'))
#             self.model.add(Dense(64, activation='relu'))
#             self.model.add(Dense(32, activation='relu'))
#             self.model.add(Dense(np.array(actions).shape[0], activation='softmax'))

#             self.model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        
#         else:
#             self.model = tf.keras.load_model(load_from_file)
    
#     def trainModel(self, X_train, y_train, epochs = 1000):
#         history = self.model.fit(X_train, y_train, epochs=epochs, callbacks=[self.tb_callback])
        
#     def predict(self, y):
#         return self.model.predict(y)

# %% [markdown]
# Loading Data and testing the model

# %%
sequences, labels, actions = DataGenerator.loadData()
actions
# Out:
# ['5', 'Hello', 'Thanks']

# %%
actions = np.array(actions)
actions.shape[0]
# Out:
# 3

# %%
np.array(sequences).shape
# Out:
# (63, 30, 126)

# %%
np.array(labels).shape
# Out:
# (63,)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
X = np.array(sequences)
X.shape
# Out:
# (63, 30, 126)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (56, 30, 126)
# (7, 30, 126)
# (56, 3)
# (7, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
log_dir = os.path.join('Logs')

model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,126)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
tb_callback = TensorBoard(log_dir=log_dir)
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 2/2 [==============================] - 9s 204ms/step - loss: 1.1162 - categorical_accuracy: 0.5893
# Epoch 2/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 0.8613 - categorical_accuracy: 0.9464
# Epoch 3/2000
# 2/2 [==============================] - 0s 172ms/step - loss: 0.6173 - categorical_accuracy: 0.9464
# Epoch 4/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.1739 - categorical_accuracy: 0.9464
# Epoch 5/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 0.1168 - categorical_accuracy: 0.9464
# Epoch 6/2000
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1133 - categorical_accuracy: 0.9464
# Epoch 7/2000
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0861 - categorical_accuracy: 0.9464
# Epoch 8/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0665 - categorical_accuracy: 0.9464
# Epoch 9/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0549 - categorical_accuracy: 0.9464
# Epoch 10/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0428 - categorical_accuracy: 1.0000
# Epoch 11/2000
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0335 - categorical_accuracy: 1.0000
# Epoch 12/2000
# 2/2 [==============================] - 0s 138ms/step - loss: 2.4966 - categorical_accuracy: 0.9464
# Epoch 13/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.2078 - categorical_accuracy: 0.9821
# Epoch 14/2000
# 2/2 [==============================] - 0s 123ms/step - loss: 16.6735 - categorical_accuracy: 0.8929
# Epoch 15/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0848 - categorical_accuracy: 0.9464
# Epoch 16/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 0.8530 - categorical_accuracy: 0.9464
# Epoch 17/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 22.7769 - categorical_accuracy: 0.8750
# Epoch 18/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 19.7989 - categorical_accuracy: 0.8571
# Epoch 19/2000
# 2/2 [==============================] - 0s 117ms/step - loss: 8.0691 - categorical_accuracy: 0.8393
# Epoch 20/2000
# 2/2 [==============================] - 0s 128ms/step - loss: 10.3259 - categorical_accuracy: 0.8750
# Epoch 21/2000
# 2/2 [==============================] - 0s 167ms/step - loss: 7.5973 - categorical_accuracy: 0.9107
# Epoch 22/2000
# 2/2 [==============================] - 0s 107ms/step - loss: 2.4257 - categorical_accuracy: 0.9107
# Epoch 23/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 17.2975 - categorical_accuracy: 0.8571
# Epoch 24/2000
# 2/2 [==============================] - 0s 155ms/step - loss: 18.8285 - categorical_accuracy: 0.8214
# Epoch 25/2000
# 2/2 [==============================] - 0s 148ms/step - loss: 3.8176 - categorical_accuracy: 0.9107
# Epoch 26/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 5.3021 - categorical_accuracy: 0.8929
# Epoch 27/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 2.8585 - categorical_accuracy: 0.9286
# Epoch 28/2000
# 2/2 [==============================] - 0s 113ms/step - loss: 5.1599 - categorical_accuracy: 0.9286
# Epoch 29/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 5.9105 - categorical_accuracy: 0.9286
# Epoch 30/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 4.5708 - categorical_accuracy: 0.9286
# Epoch 31/2000
# 2/2 [==============================] - 0s 170ms/step - loss: 29.6739 - categorical_accuracy: 0.8571
# Epoch 32/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 60.3897 - categorical_accuracy: 0.6607
# Epoch 33/2000
# 2/2 [==============================] - 0s 143ms/step - loss: 40.3532 - categorical_accuracy: 0.7500
# Epoch 34/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 14.2165 - categorical_accuracy: 0.8750
# Epoch 35/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 16.1185 - categorical_accuracy: 0.9286
# Epoch 36/2000
# 2/2 [==============================] - 0s 98ms/step - loss: 37.7294 - categorical_accuracy: 0.9286
# Epoch 37/2000
# 2/2 [==============================] - 0s 123ms/step - loss: 20.0832 - categorical_accuracy: 0.9464
# Epoch 38/2000
# 2/2 [==============================] - 0s 98ms/step - loss: 32.1194 - categorical_accuracy: 0.9286
# Epoch 39/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 33.9160 - categorical_accuracy: 0.8929
# Epoch 40/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 43.8696 - categorical_accuracy: 0.8750
# Epoch 41/2000
# 2/2 [==============================] - 0s 88ms/step - loss: 23.3689 - categorical_accuracy: 0.9464
# Epoch 42/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 42.8399 - categorical_accuracy: 0.9464
# Epoch 43/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 24.9211 - categorical_accuracy: 0.9464
# Epoch 44/2000
# 2/2 [==============================] - 0s 125ms/step - loss: 28.9429 - categorical_accuracy: 0.9107
# Epoch 45/2000
# 2/2 [==============================] - 0s 146ms/step - loss: 11.9098 - categorical_accuracy: 0.9286
# Epoch 46/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 14.1239 - categorical_accuracy: 0.9464
# Epoch 47/2000
# 2/2 [==============================] - 0s 124ms/step - loss: 24.5303 - categorical_accuracy: 0.9464
# Epoch 48/2000
# 2/2 [==============================] - 0s 216ms/step - loss: 15.3287 - categorical_accuracy: 0.9464
# Epoch 49/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 33.4199 - categorical_accuracy: 0.8214
# Epoch 50/2000
# 2/2 [==============================] - 0s 111ms/step - loss: 30.5969 - categorical_accuracy: 0.9464
# Epoch 51/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 50.5118 - categorical_accuracy: 0.9464
# Epoch 52/2000
# 2/2 [==============================] - 0s 155ms/step - loss: 46.9720 - categorical_accuracy: 0.9464
# Epoch 53/2000
# 2/2 [==============================] - 0s 137ms/step - loss: 35.4351 - categorical_accuracy: 0.9464
# Epoch 54/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 15.2761 - categorical_accuracy: 0.9464
# Epoch 55/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 13.8650 - categorical_accuracy: 0.9464
# Epoch 56/2000
# 2/2 [==============================] - 0s 128ms/step - loss: 10.6311 - categorical_accuracy: 0.9286
# Epoch 57/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 152.9265 - categorical_accuracy: 0.8214
# Epoch 58/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 264.4353 - categorical_accuracy: 0.7679
# Epoch 59/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 206.0972 - categorical_accuracy: 0.7679
# Epoch 60/2000
# 2/2 [==============================] - 0s 123ms/step - loss: 246.1265 - categorical_accuracy: 0.7679
# Epoch 61/2000
# 2/2 [==============================] - 0s 134ms/step - loss: 110.7515 - categorical_accuracy: 0.8750
# Epoch 62/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 114.6416 - categorical_accuracy: 0.8929
# Epoch 63/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 139.5710 - categorical_accuracy: 0.8571
# Epoch 64/2000
# 2/2 [==============================] - 0s 107ms/step - loss: 136.6218 - categorical_accuracy: 0.8929
# Epoch 65/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 173.2476 - categorical_accuracy: 0.6964
# Epoch 66/2000
# 2/2 [==============================] - 0s 133ms/step - loss: 262.7112 - categorical_accuracy: 0.8036
# Epoch 67/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 198.5148 - categorical_accuracy: 0.6071
# Epoch 68/2000
# 2/2 [==============================] - 0s 107ms/step - loss: 214.4049 - categorical_accuracy: 0.3929
# Epoch 69/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 712.7413 - categorical_accuracy: 0.2321
# Epoch 70/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 250.8712 - categorical_accuracy: 0.4821
# Epoch 71/2000
# 2/2 [==============================] - 0s 111ms/step - loss: 307.8735 - categorical_accuracy: 0.8571
# Epoch 72/2000
# 2/2 [==============================] - 0s 98ms/step - loss: 258.1253 - categorical_accuracy: 0.9286
# Epoch 73/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 220.2273 - categorical_accuracy: 0.9464
# Epoch 74/2000
# 2/2 [==============================] - 0s 148ms/step - loss: 268.3135 - categorical_accuracy: 0.9286
# Epoch 75/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 119.3151 - categorical_accuracy: 0.8571
# Epoch 76/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 173.8844 - categorical_accuracy: 0.6250
# Epoch 77/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 313.3477 - categorical_accuracy: 0.5893
# Epoch 78/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 105.2418 - categorical_accuracy: 0.8393
# Epoch 79/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 159.2660 - categorical_accuracy: 0.8571
# Epoch 80/2000
# 2/2 [==============================] - 0s 120ms/step - loss: 82.4662 - categorical_accuracy: 0.9107
# Epoch 81/2000
# 2/2 [==============================] - 0s 127ms/step - loss: 69.3790 - categorical_accuracy: 0.9464
# Epoch 82/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 27.5777 - categorical_accuracy: 0.8750
# Epoch 83/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 28.0993 - categorical_accuracy: 0.8929
# Epoch 84/2000
# 2/2 [==============================] - 0s 115ms/step - loss:
2000
# 2/2 [==============================] - 0s 103ms/step - loss: 79.8872 - categorical_accuracy: 0.8036
# Epoch 126/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 110.9276 - categorical_accuracy: 0.7143
# Epoch 127/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 152.3457 - categorical_accuracy: 0.6786
# Epoch 128/2000
# 2/2 [==============================] - 0s 95ms/step - loss: 60.7307 - categorical_accuracy: 0.6786
# Epoch 129/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 86.9187 - categorical_accuracy: 0.8214
# Epoch 130/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 66.0812 - categorical_accuracy: 0.8214
# Epoch 131/2000
# 2/2 [==============================] - 0s 136ms/step - loss: 235.2280 - categorical_accuracy: 0.8036
# Epoch 132/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 211.3423 - categorical_accuracy: 0.8036
# Epoch 133/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 115.7754 - categorical_accuracy: 0.8036
# Epoch 134/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 71.6032 - categorical_accuracy: 0.8036
# Epoch 135/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 64.3645 - categorical_accuracy: 0.4821
# Epoch 136/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 76.6561 - categorical_accuracy: 0.4286
# Epoch 137/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 30.1209 - categorical_accuracy: 0.6071
# Epoch 138/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 63.4627 - categorical_accuracy: 0.7321
# Epoch 139/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 68.1663 - categorical_accuracy: 0.7857
# Epoch 140/2000
# 2/2 [==============================] - 0s 139ms/step - loss: 88.8089 - categorical_accuracy: 0.7321
# Epoch 141/2000
# 2/2 [==============================] - 0s 126ms/step - loss: 87.8398 - categorical_accuracy: 0.5179
# Epoch 142/2000
# 2/2 [==============================] - 0s 142ms/step - loss: 93.3998 - categorical_accuracy: 0.7679
# Epoch 143/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 86.8928 - categorical_accuracy: 0.8214
# Epoch 144/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 50.3125 - categorical_accuracy: 0.8036
# Epoch 145/2000
# 2/2 [==============================] - 0s 121ms/step - loss: 53.2620 - categorical_accuracy: 0.7679
# Epoch 146/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 42.5057 - categorical_accuracy: 0.7500
# Epoch 147/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 24.2492 - categorical_accuracy: 0.7321
# Epoch 148/2000
# 2/2 [==============================] - 0s 96ms/step - loss: 38.0107 - categorical_accuracy: 0.8036
# Epoch 149/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 9.5141 - categorical_accuracy: 0.7857
# Epoch 150/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 8.6015 - categorical_accuracy: 0.6964
# Epoch 151/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 10.0225 - categorical_accuracy: 0.8750
# Epoch 152/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 10.5799 - categorical_accuracy: 0.9286
# Epoch 153/2000
# 2/2 [==============================] - 0s 142ms/step - loss: 8.0379 - categorical_accuracy: 0.9286
# Epoch 154/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 8.1026 - categorical_accuracy: 0.8571
# Epoch 155/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 9.9726 - categorical_accuracy: 0.8214
# Epoch 156/2000
# 2/2 [==============================] - 0s 170ms/step - loss: 6.5092 - categorical_accuracy: 0.8393
# Epoch 157/2000
# 2/2 [==============================] - 0s 119ms/step - loss: 10.5262 - categorical_accuracy: 0.7500
# Epoch 158/2000
# 2/2 [==============================] - 0s 93ms/step - loss: 11.0733 - categorical_accuracy: 0.5536
# Epoch 159/2000
# 2/2 [==============================] - 0s 103ms/step - loss: 7.9511 - categorical_accuracy: 0.5000
# Epoch 160/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 7.1552 - categorical_accuracy: 0.8393
# Epoch 161/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 6.3676 - categorical_accuracy: 0.8214
# Epoch 162/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 3.6837 - categorical_accuracy: 0.8393
# Epoch 163/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 2.4431 - categorical_accuracy: 0.8929
# Epoch 164/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 1.0358 - categorical_accuracy: 0.9464
# Epoch 165/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 3.3503 - categorical_accuracy: 0.8929
# Epoch 166/2000
# 2/2 [==============================] - 0s 91ms/step - loss: 2.5927 - categorical_accuracy: 0.8571
# Epoch 167/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 2.3689 - categorical_accuracy: 0.8571
# Epoch 168/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 1.9271 - categorical_accuracy: 0.8393
# Epoch 169/2000
# 2/2 [==============================] - 0s 98ms/step - loss: 2.7103 - categorical_accuracy: 0.8750
# Epoch 170/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 2.7932 - categorical_accuracy: 0.8571
# Epoch 171/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 3.0718 - categorical_accuracy: 0.9107
# Epoch 172/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 4.0104 - categorical_accuracy: 0.8750
# Epoch 173/2000
# 2/2 [==============================] - 0s 98ms/step - loss: 2.1012 - categorical_accuracy: 0.9107
# Epoch 174/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 4.2189 - categorical_accuracy: 0.9107
# Epoch 175/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 7.3138 - categorical_accuracy: 0.8929
# Epoch 176/2000
# 2/2 [==============================] - 0s 92ms/step - loss: 22.6723 - categorical_accuracy: 0.8750
# Epoch 177/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 16.7531 - categorical_accuracy: 0.8571
# Epoch 178/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 41.7868 - categorical_accuracy: 0.8036
# Epoch 179/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 15.1459 - categorical_accuracy: 0.8750
# Epoch 180/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 10.0982 - categorical_accuracy: 0.7143
# Epoch 181/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 10.2940 - categorical_accuracy: 0.5714
# Epoch 182/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 0.4015 - categorical_accuracy: 0.9286
# Epoch 183/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 5.7930 - categorical_accuracy: 0.8929
# Epoch 184/2000
# 2/2 [==============================] - 0s 96ms/step - loss: 2.4396 - categorical_accuracy: 0.8750
# Epoch 185/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 10.4888 - categorical_accuracy: 0.8929
# Epoch 186/2000
# 2/2 [==============================] - 0s 94ms/step - loss: 8.4629 - categorical_accuracy: 0.8929
# Epoch 187/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 2.9304 - categorical_accuracy: 0.9107
# Epoch 188/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 8.2461 - categorical_accuracy: 0.8929
# Epoch 189/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 18.6336 - categorical_accuracy: 0.9286
# Epoch 190/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 9.3508 - categorical_accuracy: 0.8929
# Epoch 191/2000
# 2/2 [==============================] - 0s 93ms/step - loss: 5.0125 - categorical_accuracy: 0.9107
# Epoch 192/2000
# 2/2 [==============================] - 0s 99ms/step - loss: 7.0051 - categorical_accuracy: 0.9107
# Epoch 193/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 4.2777 - categorical_accuracy: 0.9107
# Epoch 194/2000
# 2/2 [==============================] - 0s 107ms/step - loss: 4.5922 - categorical_accuracy: 0.8393
# Epoch 195/2000
# 2/2 [==============================] - 0s 116ms/step - loss: 5.6113 - categorical_accuracy: 0.8929
# Epoch 196/2000
# 2/2 [==============================] - 0s 119ms/step - loss: 7.6164 - categorical_accuracy: 0.8036
# Epoch 197/2000
# 2/2 [==============================] - 0s 121ms/step - loss: 5.2046 - categorical_accuracy: 0.8571
# Epoch 198/2000
# 2/2 [==============================] - 0s 126ms/step - loss: 10.5137 - categorical_accuracy: 0.9107
# Epoch 199/2000
# 2/2 [==============================] - 0s 126ms/step - loss: 4.5835 - categorical_accuracy: 0.8750
# Epoch 200/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 7.3363 - categorical_accuracy: 0.8214
# Epoch 201/2000
# 2/2 [==============================] - 0s 136ms/step - loss: 4.6104 - categorical_accuracy: 0.9107
# Epoch 202/2000
# 2/2 [==============================] - 0s 143ms/step - loss: 5.9850 - categorical_accuracy: 0.8750
# Epoch 203/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 5.9088 - categorical_accuracy: 0.9107
# Epoch 204/2000
# 2/2 [==============================] - 0s 116ms/step - loss: 3.3644 - categorical_accuracy: 0.8929
# Epoch 205/2000
# 2/2 [==============================] - 0s 130ms/step - loss: 0.7613 - categorical_accuracy: 0.9464
# Epoch 206/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 3.1246 - categorical_accuracy: 0.9464
# Epoch 207/2000
# 2/2 [==============================] - 0s 326ms/step - loss: 5.8772 - categorical_accuracy: 0.9464
# Epoch 208/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 5.4852 - categorical_accuracy: 0.9286
# Epoch 209/2000
# 2/2 [==============================] - 0s 111ms/step - loss: 3.3361 - categorical_accuracy: 0.9286
# Epoch 210/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 1.4696 - categorical_accuracy: 0.9286
# Epoch 211/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 3.0654 - categorical_accuracy: 0.8214
# Epoch 212/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 2.2529 - categorical_accuracy: 0.8750
# Epoch 213/2000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.8768 - categorical_accuracy: 0.9286
# Epoch 214/2000
# 2/2 [==============================] - 0s 111ms/step - loss: 1.5186 - categorical_accuracy: 0.8750
# Epoch 215/2000
# 2/2 [==============================] - 0s 172ms/step - loss: 0.8299 - categorical_accuracy: 0.8571
# Epoch 216/2000
# 2/2 [==============================] - 0s 126ms/step - loss: 2.9002 - categorical_accuracy: 0.8393
# Epoch 217/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.4395 - categorical_accuracy: 0.8750
# Epoch 218/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 3.2995 - categorical_accuracy: 0.9107
# Epoch 219/2000
# 2/2 [==============================] - 0s 134ms/step - loss: 0.5843 - categorical_accuracy: 0.8750
# Epoch 220/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 4.1761 - categorical_accuracy: 0.8393
# Epoch 221/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 6.8123 - categorical_accuracy: 0.8750
# Epoch 222/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 4.2615 - categorical_accuracy: 0.8214
# Epoch 223/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 3.0480 - categorical_accuracy: 0.8393
# Epoch 224/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 1.8448 - categorical_accuracy: 0.8929
# Epoch 225/2000
# 2/2 [==============================] - 0s 134ms/step - loss: 2.2371 - categorical_accuracy: 0.9286
# Epoch 226/2000
# 2/2 [==============================] - 0s 122ms/step - loss: 2.4761 - categorical_accuracy: 0.9286
# Epoch 227/2000
# 2/2 [==============================] - 0s 117ms/step - loss: 2.2181 - categorical_accuracy: 0.9464
# Epoch 228/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 1.0326 - categorical_accuracy: 0.9286
# Epoch 229/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 0.6559 - categorical_accuracy: 0.8929
# Epoch 230/2000
# 2/2 [==============================] - 0s 120ms/step - loss: 1.2904 - categorical_accuracy: 0.8929
# Epoch 231/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.9836 - categorical_accuracy: 0.8929
# Epoch 232/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.7133 - categorical_accuracy: 0.9107
# Epoch 233/2000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.5021 - categorical_accuracy: 0.9107
# Epoch 234/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.3407 - categorical_accuracy: 0.9286
# Epoch 235/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 0.2170 - categorical_accuracy: 0.9643
# Epoch 236/2000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.2273 - categorical_accuracy: 0.9107
# Epoch 237/2000
# 2/2 [==============================] - 0s 132ms/step - loss: 0.2420 - categorical_accuracy: 0.9107
# Epoch 238/2000
# 2/2 [==============================] - 0s 126ms/step - loss: 0.2241 - categorical_accuracy: 0.9286
# Epoch 239/2000
# 2/2 [==============================] - 0s 126ms/step - loss: 0.1987 - categorical_accuracy: 0.9464
# Epoch 240/2000
# 2/2 [==============================] - 0s 123ms/step - loss: 0.1432 - categorical_accuracy: 0.9286
# Epoch 241/2000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.1148 - categorical_accuracy: 0.9286
# Epoch 242/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 0.1174 - categorical_accuracy: 0.9464
# Epoch 243/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 0.1360 - categorical_accuracy: 0.9286
# Epoch 244/2000
# 2/2 [==============================] - 0s 117ms/step - loss: 0.2900 - categorical_accuracy: 0.9464
# Epoch 245/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0854 - categorical_accuracy: 0.9464
# Epoch 246/2000
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1974 - categorical_accuracy: 0.9286
# Epoch 247/2000
# 2/2 [==============================] - 0s 137ms/step - loss: 0.1374 - categorical_accuracy: 0.9643
# Epoch 248/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.2265 - categorical_accuracy: 0.9286
# Epoch 249/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 0.1497 - categorical_accuracy: 0.9464
# Epoch 250/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1777 - categorical_accuracy: 0.9821
# Epoch 251/2000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.2063 - categorical_accuracy: 0.9643
# Epoch 252/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.9398 - categorical_accuracy: 0.8929
# Epoch 253/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 3.3164 - categorical_accuracy: 0.8214
# Epoch 254/2000
# 2/2 [==============================] - 0s 93ms/step - loss: 2.4873 - categorical_accuracy: 0.8571
# Epoch 255/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 3.0009 - categorical_accuracy: 0.8393
# Epoch 256/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 4.4969 - categorical_accuracy: 0.9286
# Epoch 257/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 4.5864 - categorical_accuracy: 0.8929
# Epoch 258/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 3.6815 - categorical_accuracy: 0.8036
# Epoch 259/2000
# 2/2 [==============================] - 0s 97ms/step - loss: 5.3717 - categorical_accuracy: 0.8571
# Epoch 260/2000
# 2/2 [==============================] - 0s 102ms/step - loss: 5.1308 - categorical_accuracy: 0.8036
# Epoch 261/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 1.9957 - categorical_accuracy: 0.8214
# Epoch 262/2000
# 2/2 [==============================] - 0s 100ms/step - loss: 1.5866 - categorical_accuracy: 0.8393
# Epoch 263/2000
# 2/2 [==============================] - 0s 117ms/step - loss: 1.5200 - categorical_accuracy: 0.8571
# Epoch 264/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 1.9045 - categorical_accuracy: 0.8571
# Epoch 265/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 0.9767 - categorical_accuracy: 0.9464
# Epoch 266/2000
# 2/2 [==============================] - 0s 97ms/step - loss: 0.5090 - categorical_accuracy: 0.9464
# Epoch 267/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 0.3551 - categorical_accuracy: 0.9107
# Epoch 268/2000
# 2/2 [==============================] - 0s 405ms/step - loss: 0.4819 - categorical_accuracy: 0.9107
# Epoch 269/2000
# 2/2 [==============================] - 0s 101ms/step - loss: 0.3101 - categorical_accuracy: 0.9643
# Epoch 270/2000
# 2/2 [==============================] - 0s 109ms/step - loss: 0.4111 - categorical_accuracy: 0.9643
# Epoch 271/2000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.7157 - categorical_accuracy: 0.9107
# Epoch 272/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.5682 - categorical_accuracy: 0.9643
# Epoch 273/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.8481 - categorical_accuracy: 0.9286
# Epoch 274/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.4649 - categorical_accuracy: 0.9286
# Epoch 275/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.4573 - categorical_accuracy: 0.9464
# Epoch 276/2000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0754 - categorical_accuracy: 0.9464
# Epoch 277/2000
# 2/2 [==============================] - 0s 125ms/step - loss: 0.4230 - categorical_accuracy: 0.9286
# Epoch 278/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.3966 - categorical_accuracy: 0.9464
# Epoch 279/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.2505 - categorical_accuracy: 0.9286
# Epoch 280/2000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0674 - categorical_accuracy: 0.9821
# Epoch 281/2000
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0204 - categorical_accuracy: 0.9821
# Epoch 282/2000
# 2/2 [==============================] - 0s 114ms/step - loss: 0.2163 - categorical_accuracy: 0.9464
# Epoch 283/2000
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0237 - categorical_accuracy: 0.9821
# Epoch 284/2000
# 2/2 [==============================] - 0s 128ms/step - loss: 0.3057 - categorical_accuracy: 0.9286
# Epoch 285/2000
# 2/2 [==============================] - 0s 176ms/step - loss: 0.0872 - categorical_accuracy: 0.9643
# Epoch 286/2000
# 2/2 [==============================] - 0s 127ms/step - loss: 0.1174 - categorical_accuracy: 0.9643
# Epoch 287/2000
# 2/2 [==============================] - 0s 349ms/step - loss: 0.1803 - categorical_accuracy: 0.9643
# Epoch 288/2000
# 2/2 [==============================] - 0s 138ms/step - loss: 0.0576 - categorical_accuracy: 0.9821
# Epoch 289/2000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0918 - categorical_accuracy: 0.9643
# Epoch 290/2000
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0457 - categorical_accuracy: 0.9643
# Epoch 291/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0528 - categorical_accuracy: 0.9821
# Epoch 292/2000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0773 - categorical_accuracy: 0.9643
# Epoch 293/2000
# 2/2 [==============================] - 0s 130ms/step - loss: 0.0658 - categorical_accuracy: 0.9821
# Epoch 294/2000
# 2/2 [==============================] - 0s 111ms/step - loss: 0.1271 - categorical_accuracy: 0.9464
# Epoch 295/2000
# 2/2 [==============================] - 0s 178ms/step - loss: 0.0276 - categorical_accuracy: 0.9821
# Epoch 296/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 0.2707 - categorical_accuracy: 0.9464
# Epoch 297/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0360 - categorical_accuracy: 0.9821
# Epoch 298/2000
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0380 - categorical_accuracy: 0.9821
# Epoch 299/2000
# 2/2 [==============================] - 0s 116ms/step - loss: 0.1444 - categorical_accuracy: 0.9643
# Epoch 300/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0925 - categorical_accuracy: 0.9643
# Epoch 301/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0350 - categorical_accuracy: 0.9821
# Epoch 302/2000
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0419 - categorical_accuracy: 0.9821
# Epoch 303/2000
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0194 - categorical_accuracy: 1.0000
# Epoch 304/2000
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0232 - categorical_accuracy: 0.9821
# Epoch 305/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0182 - categorical_accuracy: 1.0000
# Epoch 306/2000
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0166 - categorical_accuracy: 1.0000
# Epoch 307/2000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0137 - categorical_accuracy: 1.0000
# Epoch 308/2000
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0237 - categorical_accuracy: 0.9821
# Epoch 309/2000
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0186 - categorical_accuracy: 1.0000
# Epoch 310/2000
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0120 - categorical_accuracy: 1.0000
# Epoch 311/2000
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0169 - categorical_accuracy: 1.0000
# Epoch 312/2000
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0150 - categorical_accuracy: 1.0000
# Epoch 313/2000
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0173 - categorical_accuracy: 0.9821
# Epoch 314/2000
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0145 - categorical_accuracy: 1.0000
# Epoch 315/2000
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0100 - categorical_accuracy: 1.0000
# Epoch 316/2000
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0107 - categorical_accuracy: 1.0000
# Epoch 317/2000
#
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Thanks
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\SIH\LSTMInterface.ipynb Cell 37' in <cell line: 9>()
#      <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000037?line=12'>13</a> ret, frame = cap.read()
#      <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000037?line=14'>15</a> # Make detections
# ---> <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000037?line=15'>16</a> image, results = MediapipeUtil.MediapipeDetection(frame, holistic)
#      <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000037?line=16'>17</a> # print(results)
#      <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000037?line=17'>18</a>
#      <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000037?line=18'>19</a> # Draw landmarks
#      <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000037?line=19'>20</a> MediapipeUtil.draw_styled_landmarks(image, results)
#
# d:\SIH\LSTMInterface.ipynb Cell 2' in MediapipeUtil.MediapipeDetection(cls, image, model)
#       <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000001?line=3'>4</a> image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000001?line=4'>5</a> image.flags.writeable = False
# ----> <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000001?line=5'>6</a> results = model.process(image)
#       <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000001?line=6'>7</a> image.flags.writeable = True
#       <a href='vscode-notebook-cell:/d%3A/SIH/LSTMInterface.ipynb#ch0000001?line=7'>8</a> image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
# File D:\SIH\asl\lib\site-packages\mediapipe\python\solutions\holistic.py:160, in Holistic.process(self, image)
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solutions/holistic.py?line=135'>136</a> def process(self, image: np.ndarray) -> NamedTuple:
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solutions/holistic.py?line=136'>137</a>   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solutions/holistic.py?line=137'>138</a>
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solutions/holistic.py?line=138'>139</a>   Args:
#    (...)
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solutions/holistic.py?line=156'>157</a>          "enable_segmentation" is set to true.
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solutions/holistic.py?line=157'>158</a>   """
# --> <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solutions/holistic.py?line=159'>160</a>   results = super().process(input_data={'image': image})
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solutions/holistic.py?line=160'>161</a>   if results.pose_landmarks:
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solutions/holistic.py?line=161'>162</a>     for landmark in results.pose_landmarks.landmark:
#
# File D:\SIH\asl\lib\site-packages\mediapipe\python\solution_base.py:334, in SolutionBase.process(self, input_data)
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=327'>328</a>   else:
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=328'>329</a>     self._graph.add_packet_to_input_stream(
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=329'>330</a>         stream=stream_name,
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=330'>331</a>         packet=self._make_packet(input_stream_type,
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=331'>332</a>                                  data).at(self._simulated_timestamp))
# --> <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=333'>334</a> self._graph.wait_until_idle()
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=334'>335</a> # Create a NamedTuple object where the field names are mapping to the graph
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=335'>336</a> # output stream names.
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=336'>337</a> solution_outputs = collections.namedtuple(
#     <a href='file:///d%3A/SIH/asl/lib/site-packages/mediapipe/python/solution_base.py?line=337'>338</a>     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:

# %%
cap.release()
cv2.destroyAllWindows()
